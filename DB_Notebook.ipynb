# %% [markdown]
# CREATING CATALOG

# %%
# %sql
CREATE CATALOG cars_catalog;

# %%
# %sql
USE CATALOG cars_catalog;

# %%
# %sql
SHOW CATALOGS;

# %% [markdown]
# CREATING SCHEMA

# %%
# %sql
CREATE SCHEMA cars_catalog.silver;

# %%
# %sql
CREATE SCHEMA cars_catalog.gold;

# %%
# %sql 
USE SCHEMA silver;
USE SCHEMA gold;

# %%
# %sql
SHOW SCHEMAS IN cars_catalog;

# %%
# %sql
DESCRIBE SCHEMA cars_catalog.silver;

# %%
# %sql
DESCRIBE SCHEMA cars_catalog.gold;
